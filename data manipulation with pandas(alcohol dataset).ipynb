# %%
import pandas as pd

# %%
df=pd.read_csv('c:/Users/HP/Downloads/world_alcohol - world_alcohol.csv')

# %%
df
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 2            Wine           1.62
# 3            Beer           4.27
# ...

# %% [markdown]
# # Write a Pandas program to filter those records where WHO region matches with multiple values (Africa, Eastern Mediterranean, Europe) from world alcohol consumption dataset

# %%
condition1= df['WHO region']=='Africa'

# %%
condition2= df['WHO region']=='Europe'

# %%
condition3= df['WHO region']=='Eastern Mediterranean'

# %%
regions=condition1+condition2+condition3

# %%
df[regions]
# Out:
#     Year WHO region            Country Beverage Types  Display Value
# 2   1985     Africa       Cte d'Ivoire           Wine           1.62
# 6   1987     Africa          Mauritius           Wine           0.13
# 7   1985     Africa             Angola        Spirits           0.39
# 9   1984     Africa            Nigeria          Other           6.10
# 10  1987     Africa           Botswana           Wine           0.20
# ..   ...        ...                ...            ...            ...
# 93  1987     Africa         Madagascar          Other            NaN
# 94  1985     Europe            Ukraine        Spirits           3.06
# 95  1984     Africa              Niger          Other           0.00
# 96  1985     Europe         Luxembourg           Wine           7.38
# 98  1984     Africa  Equatorial Guinea           Wine           0.00
#
# [69 rows x 5 columns]

# %% [markdown]
# # Write a Pandas program to filter those records which not appears in a given list from world alcohol consumption dataset.

# %%
liste=['Africa','Europe','Eastern Mediterranean']

# %%
other_regions= ~df['WHO region'].isin(liste)

# %%
df[other_regions]
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# 5   1987         Americas                              Guatemala
# 8   1986         Americas                    Antigua and Barbuda
# 11  1989         Americas                              Guatemala
# 12  1985  Western Pacific       Lao People's Democratic Republic
# 14  1985  Western Pacific                               Viet Nam
# 16  1984         Americas                             Costa Rica
# 20  1986  South-East Asia                                Myanmar
# 21  1989         Americas                             Costa Rica
# 28  1987  Western Pacific                               Viet Nam
# ...

# %% [markdown]
# #  Write a Pandas program to filter all records where the average consumption of beverages per person from .5 to 2.50 in world alcohol consumption dataset

# %%
average_consumption= (df['Display Value'] >= .5) & (df['Display Value']<=2.50)

# %%
df[average_consumption]
# Out:
#     Year             WHO region  \
# 1   1986               Americas
# 2   1985                 Africa
# 4   1987               Americas
# 8   1986               Americas
# 11  1989               Americas
# 17  1989                 Africa
# 18  1984                 Europe
# 19  1984                 Africa
# 26  1985                 Europe
# 27  1984  Eastern Mediterranean
# 32  1989                 Africa
# 34  1986                 Europe
# 35  1985               Americas
# 40  1987                 Europe
# 46  1987               Americas
# 48  1987               Americas
# 49  1986                 Europe
# 54  1984               Americas
# 64  1989               Americas
# 70  1986                 Africa
# 71  1985                 Africa
# 74  1986               Americas
# 79  1989                 Europe
# 80  1985                 Africa
# 82  1987                 Europe
# 86  1986               Americas
# 89  1986  Eastern Mediterranean
#
# ...

# %% [markdown]
# # Write a Pandas program to find number of consumption of wine per person greater than 2 in world alcohol consumption dataset.

# %%
wine_consumption=(df['Beverage Types']=='Wine') &(df['Display Value']>=2)

# %%
df[wine_consumption]
# Out:
#     Year WHO region      Country Beverage Types  Display Value
# 57  1989     Europe      Croatia           Wine           5.10
# 81  1985     Europe  Netherlands           Wine           2.54
# 96  1985     Europe   Luxembourg           Wine           7.38

# %%
df[wine_consumption].count()
# Out:
# Year              3
# WHO region        3
# Country           3
# Beverage Types    3
# Display Value     3
# dtype: int64

# %% [markdown]
# # Write a Pandas program to filter rows based on row numbers ended with 0, like 0, 10, 20, 30 from world alcohol consumption dataset.

# %%
ends_with_0=df['Display Value'].str[-1]=='0'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_888\2040900802.py in <module>
# ----> 1 ends_with_0=df['Display Value'].str[-1]=='0'
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
#     183         # Replace the property with the accessor object. Inspired by:
#     184         # https://www.pydanny.com/cached-property.html
#
# ...

# %%
ends=df.apply(lambda x:x['Display Value'][-1]==0,axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_888\2344889193.py in <module>
# ----> 1 ends=df.apply(lambda x:x['Display Value'][-1]==0,axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8846             kwargs=kwargs,
#    8847         )
# -> 8848         return op.apply().__finalize__(self, method="apply")
#    8849
#    8850     def applymap(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#     731             return self.apply_raw()
#     732
# --> 733         return self.apply_standard()
#     734
#     735     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     855
#     856     def apply_standard(self):
# --> 857         results, res_index = self.apply_series_generator()
#     858
# ...

# %%
end_0=df.filter(regex='0$',axis=0)

# %%
end_0
# Out:
#     Year             WHO region                     Country Beverage Types  \
# 0   1986        Western Pacific                    Viet Nam           Wine
# 10  1987                 Africa                    Botswana           Wine
# 20  1986        South-East Asia                     Myanmar           Wine
# 30  1986                 Africa                Sierra Leone          Other
# 40  1987                 Europe                     Austria        Spirits
# 50  1985                 Europe                 Switzerland          Other
# 60  1987  Eastern Mediterranean  Iran (Islamic Republic of)          Other
# 70  1986                 Africa                  Madagascar        Spirits
# 80  1985                 Africa                      Malawi          Other
# 90  1989                 Africa                      Malawi           Wine
#
#     Display Value
# 0            0.00
# 10           0.20
# 20           0.00
# 30           4.48
# 40           1.90
# 50           0.30
# ...

# %% [markdown]
# # Write a Pandas program to select consecutive columns and also select rows with Index label 0 to 9 with some columns from world alcohol consumption dataset.

# %%
df.loc[:9,['Country','Display Value']]
# Out:
#                  Country  Display Value
# 0               Viet Nam           0.00
# 1                Uruguay           0.50
# 2           Cte d'Ivoire           1.62
# 3               Colombia           4.27
# 4  Saint Kitts and Nevis           1.98
# 5              Guatemala           0.00
# 6              Mauritius           0.13
# 7                 Angola           0.39
# 8    Antigua and Barbuda           1.55
# 9                Nigeria           6.10

# %% [markdown]
# #  Write a Pandas program to filter all records starting from the 2nd row, access every 5th row from world alcohol consumption dataset.

# %%
df[1::5]
# Out:
#     Year             WHO region  \
# 1   1986               Americas
# 6   1987                 Africa
# 11  1989               Americas
# 16  1984               Americas
# 21  1989               Americas
# 26  1985                 Europe
# 31  1986        Western Pacific
# 36  1987  Eastern Mediterranean
# 41  1986                 Europe
# 46  1987               Americas
# 51  1987                 Europe
# 56  1987        Western Pacific
# 61  1984        Western Pacific
# 66  1987  Eastern Mediterranean
# 71  1985                 Africa
# 76  1985                 Africa
# 81  1985                 Europe
# 86  1986               Americas
# 91  1989                 Europe
# 96  1985                 Europe
#
#                                               Country Beverage Types  \
# 1                                             Uruguay          Other
# 6                                           Mauritius           Wine
# ...

# %% [markdown]
# # Write a Pandas program to split the following dataframe into groups based on school code. Also check the type of GroupBy object.

# %%
student_data = pd.DataFrame({
    'school_code': ['s001','s002','s003','s001','s002','s004'],
    'class': ['V', 'V', 'VI', 'VI', 'V', 'VI'],
    'name': ['Alberto Franco','Gino Mcneill','Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes'],
    'date_Of_Birth ': ['15/05/2002','17/05/2002','16/02/1999','25/09/1998','11/05/2002','15/09/1997'],
    'age': [12, 12, 13, 13, 14, 12],
    'height': [173, 192, 186, 167, 151, 159],
    'weight': [35, 32, 33, 30, 31, 32],
    'address': ['street1', 'street2', 'street3', 'street1', 'street2', 'street4']},
    index=['S1', 'S2', 'S3', 'S4', 'S5', 'S6'])

# %%
student_data
# Out:
#    school_code class            name date_Of_Birth   age  height  weight  \
# S1        s001     V  Alberto Franco     15/05/2002   12     173      35
# S2        s002     V    Gino Mcneill     17/05/2002   12     192      32
# S3        s003    VI     Ryan Parkes     16/02/1999   13     186      33
# S4        s001    VI    Eesha Hinton     25/09/1998   13     167      30
# S5        s002     V    Gino Mcneill     11/05/2002   14     151      31
# S6        s004    VI    David Parkes     15/09/1997   12     159      32
#
#     address
# S1  street1
# S2  street2
# S3  street3
# S4  street1
# S5  street2
# S6  street4

# %%
group=student_data.groupby('school_code')

# %%
group.first()
# Out:
#             class            name date_Of_Birth   age  height  weight  address
# school_code
# s001            V  Alberto Franco     15/05/2002   12     173      35  street1
# s002            V    Gino Mcneill     17/05/2002   12     192      32  street2
# s003           VI     Ryan Parkes     16/02/1999   13     186      33  street3
# s004           VI    David Parkes     15/09/1997   12     159      32  street4

# %%
group.dtypes
# Out:
#               class    name date_Of_Birth     age height weight address
# school_code
# s001         object  object         object  int64  int64  int64  object
# s002         object  object         object  int64  int64  int64  object
# s003         object  object         object  int64  int64  int64  object
# s004         object  object         object  int64  int64  int64  object

# %%
type(group)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %% [markdown]
# # Write a Pandas program to split the following dataframe by school code and get mean, min, and max value of age for each school.

# %%
mean_age=student_data.groupby('school_code')['age'].mean()

# %%
mean_age
# Out:
# school_code
# s001    12.5
# s002    13.0
# s003    13.0
# s004    12.0
# Name: age, dtype: float64

# %%
age_min=student_data.groupby('school_code')['age'].min()

# %%
age_min
# Out:
# school_code
# s001    12
# s002    12
# s003    13
# s004    12
# Name: age, dtype: int64

# %%
age_max=student_data.groupby('school_code')['age'].max()

# %%
age_max
# Out:
# school_code
# s001    13
# s002    14
# s003    13
# s004    12
# Name: age, dtype: int64

# %% [markdown]
# # Write a Pandas program to split the following given dataframe into groups based on school code and class.

# %%
group2=student_data.groupby(['school_code','class'])

# %%
group2.first()
# Out:
#                              name date_Of_Birth   age  height  weight  address
# school_code class
# s001        V      Alberto Franco     15/05/2002   12     173      35  street1
#             VI       Eesha Hinton     25/09/1998   13     167      30  street1
# s002        V        Gino Mcneill     17/05/2002   12     192      32  street2
# s003        VI        Ryan Parkes     16/02/1999   13     186      33  street3
# s004        VI       David Parkes     15/09/1997   12     159      32  street4

# %% [markdown]
# # Create a dataframe of ten rows, four columns with random values. Convert some values to nan values. Write a Pandas program which will highlight the nan values.

# %%
import numpy as np
import seaborn as sns

# Create a random DataFrame with 10 rows and 4 columns
df2 = pd.DataFrame(np.random.randn(10, 4), columns=['A', 'B', 'C', 'D'])

# Replace some values with NaNs
df2.iloc[2, 1] = np.nan
df2.iloc[5, 3] = np.nan
df2.iloc[8, 0] = np.nan

# Define a custom color map for highlighting NaN values
cmap = sns.light_palette('yellow', as_cmap=True)

# Highlight NaN values in the DataFrame
highlighted = df2.style.background_gradient(cmap=cmap, subset=pd.IndexSlice[:, df2.columns[df.isna().any()]])

# Display the highlighted DataFrame
highlighted
# Out:
# <style type="text/css">
# #T_4c698_row0_col0, #T_4c698_row3_col3, #T_4c698_row8_col1 {
#   background-color: #f2f2dd;
#   color: #000000;
# }
# #T_4c698_row0_col1 {
#   background-color: #f8f874;
#   color: #000000;
# }
# #T_4c698_row0_col3 {
#   background-color: #f3f3d2;
#   color: #000000;
# }
# #T_4c698_row1_col0 {
#   background-color: #fdfd25;
#   color: #000000;
# }
# #T_4c698_row1_col1 {
#   background-color: #fcfc39;
#   color: #000000;
# }
# #T_4c698_row1_col3, #T_4c698_row4_col0, #T_4c698_row5_col1 {
#   background-color: #ffff00;
#   color: #000000;
# }
# #T_4c698_row2_col0 {
#   background-color: #f6f696;
#   color: #000000;
# }
# #T_4c698_row2_col1, #T_4c698_row5_col3, #T_4c698_row8_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_4c698_row2_col3 {
#   background-color: #fdfd24;
#   color: #000000;
# }
# #T_4c698_row3_col0 {
#   background-color: #f6f699;
#   color: #000000;
# }
# #T_4c698_row3_col1 {
#   background-color: #f9f95f;
#   color: #000000;
# ...

# %% [markdown]
# # Create a dataframe of ten rows, four columns with random values. Write a Pandas program to highlight dataframe’s specific columns with different colors.

# %%
def highlight_cols(s, cols):
    color = 'blue'
    if s.name in cols:
        return ['background-color: {}'.format(color)] * len(s)
    else:
        return [''] * len(s)

# %%
df2.style.apply(highlight_cols, cols=['A', 'C'])
# Out:
# <style type="text/css">
# #T_153f3_row0_col0, #T_153f3_row0_col2, #T_153f3_row1_col0, #T_153f3_row1_col2, #T_153f3_row2_col0, #T_153f3_row2_col2, #T_153f3_row3_col0, #T_153f3_row3_col2, #T_153f3_row4_col0, #T_153f3_row4_col2, #T_153f3_row5_col0, #T_153f3_row5_col2, #T_153f3_row6_col0, #T_153f3_row6_col2, #T_153f3_row7_col0, #T_153f3_row7_col2, #T_153f3_row8_col0, #T_153f3_row8_col2, #T_153f3_row9_col0, #T_153f3_row9_col2 {
#   background-color: blue;
# }
# </style>
# <table id="T_153f3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_153f3_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_153f3_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_153f3_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_153f3_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_153f3_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %% [markdown]
# # Write a Pandas program to display the dataframe in Heatmap style.

# %%
sns.heatmap(df2, cmap='coolwarm', annot=True)
# Out:
# <AxesSubplot:>
